# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix

# %% [markdown]
# Step 1: Loading the dataset

# %%
data = pd.read_csv('C:\\Users\\ANTRA RAJPUROHIT\\OneDrive\\Documents\\VS Code\\The Grip TSF\\The-Sparks-Foundation-Tasks\\data\\task2_Iris.csv')

# %%
data.head(10)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
# 8   9            4.4           2.9            1.4           0.2  Iris-setosa
# 9  10            4.9           3.1            1.5           0.1  Iris-setosa

# %% [markdown]
# Step 2: Visualizing the input data

# %%
plt.scatter(data['PetalLengthCm'], data['PetalWidthCm'])
plt.title('Input Data')
plt.xlabel('Petal Length (cm)')
plt.ylabel('Petal Width (cm)')
plt.show()

# %% [markdown]
# Step 3: Data preprocessing

# %%
X = data[['PetalLengthCm', 'PetalWidthCm']].values
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# Step 4: Model training

# %%
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(X_scaled)
print("Training complete!")
# Out:
# Training complete!
# c:\Users\ANTRA RAJPUROHIT\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# Step 5: Visualizing the model clusters

# %%
plt.scatter(X_scaled[:, 0], X_scaled[:, 1], c=kmeans.labels_, cmap='viridis')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], marker='*', s=300, c='red', label='Centroids')
plt.title('Clustered Data')
plt.xlabel('Petal Length (cm)')
plt.ylabel('Petal Width (cm)')
plt.legend()
plt.show()

# %% [markdown]
# Step 6: Calculating accuracy and confusion matrix

# %%
y_true = data['Species'].map({'Iris-setosa': 0, 'Iris-versicolor': 1, 'Iris-virginica': 2}).values
y_pred = kmeans.labels_
accuracy = accuracy_score(y_true, y_pred)
confusion_mat = confusion_matrix(y_true, y_pred)
print("Accuracy:", accuracy)
print("Confusion Matrix:")
print(confusion_mat)
# Out:
# Accuracy: 0.02666666666666667
# Confusion Matrix:
# [[ 0 50  0]
#  [ 2  0 48]
#  [46  0  4]]
